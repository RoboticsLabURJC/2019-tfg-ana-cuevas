# %% [markdown]
# # <center>Práctica 2</center>
# ## <center>Filtrado de imágenes en el dominio espacial </center>

# %%
#importamos librerías necesarias
import numpy as np
import cv2
from matplotlib import pyplot as plt
import imfunctions as imf

# %% [markdown]
# **I. Imágenes contaminadas con ruido**
#
# Considere las fuentes de ruido 'gaussian' y 'speckle' (también denominados ruido gaussiano y ruido granular, respectivamente) y contamine con ellas una imagen sintética de 8 bits, intensidad uniforme y luminancia 128. Considere que la imagen es cuadrada y de tamaño 256x256 píxeles. Indique y justifique la secuencia de instrucciones utilizada, tanto para generar la imagen como para
# añadir ruido. Tenga en cuenta que la matriz que representa la imagen debe ser de tipo uint8.
#
# Considere que las fuentes de ruido tienen media nula y su potencia media es 0.02 en los dos casos.

# %%
#generar ruido blanco
def imwhitenoise(img, m, v):
    h,w = img.shape
    nmat = np.random.standard_normal(size=(h,w))
    nmat = v*nmat + m
    print(nmat)
    print('max nmat =' + np.finfo(nmat).max)
    noisy = img + nmat
    print(noisy)
    print('max noisy pre 255 =' + np.finfo.max(noisy))
    noisy = noisy*255
    print(noisy)
    print('max noisy pos 255 =' + np.finfo.max(noisy))
    np.ceil(noisy)
    noisy.astype(np.uint8)
    return noisy

# %%
blank = np.ones((128, 128), dtype=np.uint8)*128
blank[0,0] = 0
blank[0,1] = 255
print(blank)
plt.imshow(blank, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.show()

#generar ruido blanco

blanknoise = imwhitenoise(blank, 0, 0.01)
plt.imshow(blanknoise, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# [[  0 255 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  ...
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]]
# [[-1.47937861e-02  9.58221209e-03 -1.12205489e-02 ...  1.40060296e-03
#   -1.50069815e-02 -6.28812737e-04]
#  [ 1.37888858e-02  1.84604798e-03  3.98497124e-05 ... -7.82305924e-03
#    4.71388502e-03  3.20430546e-03]
#  [-1.05375235e-02 -5.55199636e-03 -3.40497611e-03 ...  1.11557425e-02
#   -2.81616198e-02 -1.93299334e-02]
#  ...
#  [-9.91055362e-03 -8.12968741e-03 -1.27512305e-02 ...  6.70253311e-04
#    2.80301990e-04  6.66679264e-04]
#  [-2.97198452e-03  1.45385279e-02  1.06751550e-02 ... -1.26938596e-02
#    8.05482194e-04 -2.70944010e-03]
#  [-8.64816100e-03  4.07535806e-03 -7.91016804e-03 ...  1.44090275e-02
#    1.09411075e-03  6.53693405e-03]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-35529cb02894> in <module>()
#       9 #generar ruido blanco
#      10
# ---> 11 blanknoise = imwhitenoise(blank, 0, 0.01)
#      12 plt.imshow(blanknoise, cmap = 'gray')
#      13 plt.xticks([]), plt.yticks([])
#
# <ipython-input-4-24559360b3e5> in imwhitenoise(img, m, v)
#       5     nmat = v*nmat + m
#       6     print(nmat)
# ----> 7     print('max nmat =' + np.finfo(nmat).max)
#       8     noisy = img + nmat
#       9     print(noisy)
#
# ~\Anaconda3\lib\site-packages\numpy\core\getlimits.py in __new__(cls, dtype)
#     390             dtype = newdtype
#     391         if not issubclass(dtype, numeric.inexact):
# --> 392             raise ValueError("data type %r not inexact" % (dtype))
#     393         obj = cls._finfo_cache.get(dtype, None)
#     394         if obj is not None:
#
# ValueError: data type <class 'numpy.object_'> not inexact

# %%
coins = cv2.imread('coins.png', 0)
print(coins)
plt.imshow(coins, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.show()

coinsgaussian = imwhitenoise(coins, 0, 0.02)
np.ceil(coinsgaussian)
plt.imshow(coinsgaussian, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# [[49 50 48 ... 58 55 55]
#  [47 47 49 ... 56 57 55]
#  [48 48 49 ... 57 56 57]
#  ...
#  [71 70 70 ... 70 69 70]
#  [69 71 71 ... 70 72 71]
#  [69 68 69 ... 71 72 71]]
# (246, 300)
# 11992.4551079098

# %%
coins = cv2.imread('coins.png', 0)
print(coins)
plt.imshow(coins, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.show()

coinsgaussian = imf.imnoise(coins,"gauss", [0,0.01])
print(coinsgaussian)
print("shape en cuadernillo")
print(coinsgaussian.shape)
print(coinsgaussian.dtype)
coins255 = coinsgaussian*255
print(coinsgaussian)
# Out:
# [[49 50 48 ... 58 55 55]
#  [47 47 49 ... 56 57 55]
#  [48 48 49 ... 57 56 57]
#  ...
#  [71 70 70 ... 70 69 70]
#  [69 71 71 ... 70 72 71]
#  [69 68 69 ... 71 72 71]]
# (246, 300)
# [[0.18466621 0.20959837 0.19403818 ... 0.21979672 0.21480961 0.21025263]
#  [0.17398584 0.16983985 0.19985109 ... 0.2146262  0.22952721 0.21758611]
#  [0.1629972  0.19400389 0.19420421 ... 0.20972533 0.21948963 0.23109546]
#  ...
#  [0.28640194 0.27280336 0.26805131 ... 0.28653269 0.27809665 0.28203725]
#  [0.27503996 0.27015666 0.29392998 ... 0.28876089 0.28589328 0.27969803]
#  [0.26886816 0.26680986 0.26951943 ... 0.28396525 0.28012459 0.28418175]]
# shape en cuadernillo
# (246, 300)
# float64
# [[0.18466621 0.20959837 0.19403818 ... 0.21979672 0.21480961 0.21025263]
#  [0.17398584 0.16983985 0.19985109 ... 0.2146262  0.22952721 0.21758611]
#  [0.1629972  0.19400389 0.19420421 ... 0.20972533 0.21948963 0.23109546]
#  ...
#  [0.28640194 0.27280336 0.26805131 ... 0.28653269 0.27809665 0.28203725]
#  [0.27503996 0.27015666 0.29392998 ... 0.28876089 0.28589328 0.27969803]
#  [0.26886816 0.26680986 0.26951943 ... 0.28396525 0.28012459 0.28418175]]
