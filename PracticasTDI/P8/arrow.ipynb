# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
import ebma
import hbma
# %matplotlib notebook

# %%
# %matplotlib notebook
anchorframe = cv2.imread('foremanY69.png',0)
targetframe = cv2.imread('foremanY72.png',0)

newFrame, origin, direction, error= pruebasebma.EBMA(targetframe, anchorframe, 32)
plt.figure('foreman')
plt.imshow(newFrame, cmap='gray')
plt.xticks([]), plt.yticks([])  # this hides the axis ticks
for spine in plt.gca().spines.values():  #hide image border
    spine.set_visible(False)
plt.show()

# %%
fig, ax =plt.subplots()
ax.imshow(anchorframe, cmap='gray')
ax.quiver(origin[0], origin[1], direction[0], -direction[1], color =[1,0,0, 1], width = 0.0035, scale_units='xy', scale=1)
plt.show()

# %%
# %matplotlib notebook
anchorframe = cv2.imread('foremanY69.png',0)
targetframe = cv2.imread('foremanY72.png',0)
hbmaFrame, origin, direction= hbma.HBMA(targetframe, anchorframe, 16,3)
plt.figure('foreman 2')
plt.imshow(hbmaFrame, cmap='gray')
plt.xticks([]), plt.yticks([])  # this hides the axis ticks
for spine in plt.gca().spines.values():  #hide image border
    spine.set_visible(False)
plt.show()
# Out:
# 2
# 1
# <img src="data:image/png;base64,..." width="640">

# %%
fig2, ax2 =plt.subplots()
ax2.imshow(anchorframe, cmap='gray')
ax2.quiver(origin[0], origin[1], direction[0], -direction[1], color =[1,0,0, 1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from PhaseCorrelation import PhaseCorrelation

# %%
PhaseCorrelation(anchorframe, targetframe)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# float64
