# %% [markdown]
# # <center>Exercise 2</center>
# ## <center><font color=red>Spatial Image filtering</font></center>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import imfunctions as imf
# %matplotlib notebook

# %% [markdown]
# **I. Noise contaminated images**
#
# For this exercise we are going to generate images contaminated with different kinds of noise, using the function imnoise that can be found in the **file** imfuntions that was imported above. First look up some information about the following noises and how they affect images:
#     - Gaussian noise
#     - Salt and Pepper noise
#     - Speckle noise
#
# Generate an image matrix with 8 bit depth, uniform intensity of 128 and a size of 256x256 pixels (when displaying this image for this exercise remember to use the min and max value arguments in the function imshow).
#
# Now contaminate it using a white noise with a mean = 0 and variance = 0'01. Display the resulting image and its histogram.
#
# [answer cell](#whitenoise)

# %%
# %matplotlib notebook
blank = np.ones((128, 128), dtype=np.uint8)*128
print(blank)
plt.figure('blank')
plt.imshow(blank, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

#generar ruido blanco

blanknoise = imf.imnoise(blank,"gauss", [0,0.01])
plt.figure('white noise')
plt.imshow(blanknoise, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

plt.figure()
plt.hist(blanknoise.ravel(),256,[0,255])
plt.show()

cv2.imwrite('whitenoise.png',blanknoise)




plt.subplot(131),plt.imshow(blank, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.xticks([]), plt.yticks([])
for spine in plt.gca().spines.values():  #hide image border
    spine.set_visible(False)
plt.subplot(132),plt.imshow(blanknoise, cmap = 'gray', vmin = 0, vmax = 255),plt.title('whitenoise')
plt.xticks([]), plt.yticks([])
for spine in plt.gca().spines.values():  #hide image border
    spine.set_visible(False)
plt.subplot(133), plt.hist(blanknoise.ravel(),256,[0,255])

plt.show()
# Out:
# [[128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  ...
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]]
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Contaminate the image coins.png with the same gaussian noise, display the resulting image and its histogram.
#
# [answer cell](#whitecoins)

# %%
coins = cv2.imread('coins.png', 0)
print(coins)
plt.figure('coins')
plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

coinsgaussian = imf.imnoise(coins,"gauss", [0,0.01])
plt.figure('coins gaussian noise')
plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

plt.figure()
plt.hist(coinsgaussian.ravel(),256,[0,255])
plt.show()

cv2.imwrite('whitenoisecoins.png',coinsgaussian)


plt.subplot(131),plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('whitenoise')
plt.axis('off')
plt.subplot(133), plt.hist(coinsgaussian.ravel(),256,[0,255])

plt.show()
# Out:
# [[49 50 48 ... 58 55 55]
#  [47 47 49 ... 56 57 55]
#  [48 48 49 ... 57 56 57]
#  ...
#  [71 70 70 ... 70 69 70]
#  [69 71 71 ... 70 72 71]
#  [69 68 69 ... 71 72 71]]
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Salt and pepper noise**
#
# Repeat the last process with salt and pepper noise with density = 0'02. First on the image with uniform intensity and then on coins.
#
# [answer cell](#coinssp)

# %%
#for uniform intensity
plt.figure('blank2')
plt.imshow(blank, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

blanksp = imf.imnoise(blank,"sandp", 0.2)
plt.figure('salt and pepper')
plt.imshow(blanksp, cmap = 'gray')
plt.axis('off')
plt.show()

plt.figure()
plt.hist(blanksp.ravel(),256,[0,255])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#for coins
plt.figure('coins2')
plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

coinssp = imf.imnoise(coins,"sandp", 0.02)
plt.figure('salt and pepper coins')
plt.imshow(coinssp, cmap = 'gray')
plt.axis('off')
plt.show()

plt.figure()
plt.hist(coinssp.ravel(),256,[0,255])
plt.show()

plt.subplot(131),plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(coinssp, cmap = 'gray', vmin = 0, vmax = 255),plt.title('whitenoise')
plt.axis('off')
plt.subplot(133), plt.hist(coinssp.ravel(),256,[0,255])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Speckle noise**
#
# Again with Speckle noise with variance = 0'01

# %%
#for uniform intensity

plt.figure('blank3')
plt.imshow(blank, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

blankspeck = imf.imnoise(blank,"speckle", 0.01)
plt.figure('speckle')
plt.imshow(blankspeck, cmap = 'gray', vmin = 0, vmax = 255)
plt.axis('off')
plt.show()

plt.figure()
plt.hist(blankspeck.ravel(),256,[0,255])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#for coins

# %% [markdown]
# **Softening linear filters**
#
# To eliminate these kind of noises we use softening filters (low pass filter). [Here](https://docs.opencv.org/3.1.0/d4/d13/tutorial_py_filtering.html) is a link to how they work.
#
# - Averaging filter: The first step to using a linear filter is creating a Kernel. A kernel is a matrix with different characteristics depending on the filter. Averaging filters kernels must add up to one. To create one make a numpy 5x5 matrix of ones and divide it by de total size of the matrix (5x5=25) so all its digits add up to one.
#
# Now filter the image coins contaminated with Gaussian noise using the openCV function [filter2D](https://docs.opencv.org/2.4/modules/imgproc/doc/filtering.html?highlight=filter2d#filter2d) with the kernel we just created, in border type use cv2.BORDER_CONSTANT (for zero padding) what this is will be explained in the next point. Display side by side the contaminated image and the filtered image.
#
# [answer cell](#avgfilter)

# %%
kernel = np.ones((5,5),np.float32)/(5*5)
coinsfilter = cv2.filter2D(coinsgaussian, -1, kernel, borderType= cv2.BORDER_CONSTANT)

plt.figure()
plt.subplot(121),plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(122),plt.imshow(coinsfilter, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Averaging')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Padding**
#
# Padding refers to the pixels "created" next to the border of an image so the kernel can be applied for every pixel of the original image. For example in the last exercise we used zero padding, that means the created pixels around the image are all zero w,ich, when used, creates a darker border at the edge of the image as a result of averaing with 0.
#
# Other example of padding is mirror padding which creates these new pixels by copying the pixels in the image closer to the border.
# To learn more about padding options in the function filter2D click [here](https://docs.opencv.org/3.1.0/d2/de8/group__core__array.html#ga209f2f4869e304c82d07739337eae7c5)
#
# Filter the image coins contaminated with gaussian noise using the same kernel as last time but with mirror padding (cv2.BORDER_REFLECT). Display the original, zero and mirror padding images side by side and try to spot the differences.
#
# [answer cell](#padding)

# %%
coinsfiltermir = cv2.filter2D(coinsgaussian, -1, kernel, borderType= cv2.BORDER_REFLECT)

plt.figure()
plt.subplot(221),plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(222),plt.imshow(coinsfilter, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Zero padding')
plt.axis('off')
plt.subplot(223),plt.imshow(coinsfiltermir, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Mirror padding')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# To appreciate the difference in values between the two filterd images display both histograms and look and the lowest intensity vales in each of them.

# %%
plt.figure('histograms')
plt.subplot(221),plt.hist(coinsgaussian.ravel(),256,[0,256]),plt.title('Original') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.subplot(222),plt.hist(coinsfilter.ravel(),256,[0,256]),plt.title('zero') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.subplot(223),plt.hist(coinsfiltermir.ravel(),256,[0,256]),plt.title('mirror') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now change the side of the kernel to 35x35, remember that all values must add up to 1, and filter coins+gaussian with this kernel and mirror padding.
# Display the contaminated image, the filtered image with 5x5 kernel and this new image side by side.

# %%
kernel35 = np.ones((35,35),np.float32)/(35*35)

coinsfilter35 = cv2.filter2D(coinsgaussian, -1, kernel35, borderType= cv2.BORDER_REFLECT)

plt.figure()
plt.subplot(221),plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(222),plt.imshow(coinsfiltermir, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Kernel 5x5')
plt.axis('off')
plt.subplot(223),plt.imshow(coinsfilter35, cmap = 'gray', vmin = 0, vmax = 255),plt.title('kernel 35x35')
plt.axis('off')
plt.show()

plt.figure('histograms2')
plt.subplot(221),plt.hist(coinsgaussian.ravel(),256,[0,256]),plt.title('Original') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.subplot(222),plt.hist(coinsfiltermir.ravel(),256,[0,256]),plt.title('mir') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.subplot(223),plt.hist(coinsfilter35.ravel(),256,[0,256]),plt.title('35') 
plt.xlabel('Intensity')
plt.ylabel('Number of pixels')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Salt and pepper**
#
# Filter the image coins contaminated with salt and pepper noise with the 5x5 kernel and mirror padding.

# %%
filtersyp = cv2.filter2D(coinssp, -1, kernel, borderType= cv2.BORDER_REFLECT)

plt.figure()
plt.subplot(121),plt.imshow(coinssp, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(122),plt.imshow(filtersyp, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Averaging')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Non-linear softening filters**
#
# While the linear filters weer based on the convolution of an image with an external kernel, the non-linear filters operate directly with the image pixels
# - Median filter: This filter takes all the values under the kernel and assigns the median of those values to the one in the center of the kernel. This makes this filter ideal to deal with salt and pepper noise.
#
# Opencv has a specific function for this filter [medianblur](https://docs.opencv.org/2.4/modules/imgproc/doc/filtering.html?highlight=medianblur#medianblur).
#
# Filter the image coins contaminated with salt and pepper noise using a median filter with a kernel size = 5. Display the original image and this last image.
#
# Do the same for the image contaminated with gaussian noise. Which filter is better for each type of noise?
#
# [answer cell](#medianfilter)

# %%
gaussianmedian = cv2.medianBlur(coinsgaussian, 5)
sandpmedian = cv2.medianBlur(coinssp, 5)

plt.figure()
plt.subplot(221),plt.imshow(coinsgaussian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Gaussian')
plt.axis('off')
plt.subplot(222),plt.imshow(gaussianmedian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Median over Gaussian')
plt.axis('off')
plt.subplot(223),plt.imshow(coinssp, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Salt and pepper')
plt.axis('off')
plt.subplot(224),plt.imshow(sandpmedian, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Median over Salt and pepper')
plt.axis('off')
plt.show()
# Out:
# C:\Users\anusk\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Filter for edge detection**
#
# Finite difference filters or high-pass filter are filters commonly used for edge detection. Similarly to the averaging filters they use a kernel with predetermined values, in this case the values must add up to 0. There are patterns for this Kernels that are used for different things, this kernels also make a difference between vertical and horizontal borders.
#
# - Prewitt: Only uses ones and zeroes in its kernel. For horizontal borders the Kernel has one row with minus ones, another row of zeros and a last row of ones. For vertical is the transposed matrix for the horizontal kernel. The two resulting images ar complimentary.
#
# Filter the original coins image using a prewitt kernel (the function is cv2.filter2d), first get the horizontal borders, then the vertical, add the results to get the full fitered image. Display the original coins, and the three steps of the prewitt filter.
#
# Finally get the binary of the filtered image and display it.
#
# [answer cell](#prewitt)

# %%
#Prewitt kernels horizontal and vertical
prewitth = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
prewittv = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])

coinsph = cv2.filter2D(coins, -1, prewitth, borderType= cv2.BORDER_REFLECT)
coinspv = cv2.filter2D(coins, -1, prewittv, borderType= cv2.BORDER_REFLECT)

plt.figure()
plt.subplot(221),plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(223),plt.imshow(coinsph, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Prewitt horizontal')
plt.xticks([]), plt.yticks([])
plt.axis('off')
plt.subplot(224),plt.imshow(coinspv, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Prewitt vertical')
plt.axis('off')
plt.show()
# Out:
# C:\Users\anusk\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="640">

# %%
coinsprewitt = coinsph + coinspv

[thresh, coinbin] = cv2.threshold(coinsprewitt, 127, 255, cv2.THRESH_OTSU)

plt.figure()
plt.subplot(121),plt.imshow(coinsprewitt, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Coins with prewittt')
plt.axis('off')
plt.subplot(122),plt.imshow(coinbin, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Binary')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Try different threshold values for a better result.
#
# [answer cell](#prewittbinary)

# %%
[thresh, coinbin] = cv2.threshold(coinsprewitt, 160, 255, cv2.THRESH_BINARY)

plt.figure()
plt.subplot(121),plt.imshow(coinsprewitt, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Coins with prewittt')
plt.axis('off')
plt.subplot(122),plt.imshow(coinbin, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Binary')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Isotropic filter**
#
# This filter does the same as the Prewitt filter, being another high-pass filter but it does not requiere the double step of getting the vertical and horizontal edges. The kernel is a 3x3 matrix with minus one in all values but the center that is eight, this way it adds up to 0.
#
# Filter the image coins with an isotropic filter, get the binary image and display all three.
#
# [answer cell](#isotropic)

# %%
isotropic = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])

coinsiso = cv2.filter2D(coins, -1, isotropic, borderType= cv2.BORDER_REFLECT)
[thresh, coinsbiniso] = cv2.threshold(coinsiso, 160, 255, cv2.THRESH_BINARY)


plt.figure()
plt.subplot(221),plt.imshow(coins, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Original')
plt.axis('off')
plt.subplot(223),plt.imshow(coinsiso, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Isotropic')
plt.axis('off')
plt.subplot(224),plt.imshow(coinsbiniso, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Isotropic binary')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Improving results**
#
# To improve results we are going to add a step of pre-processing to the image by softening it before getting the edges. Do this preprocessing step with the two softening filter used previously, then use an isotropic filter on both softened images and get the binaries (it's recomended to look at the histogram in order to select a threhshold) of the result. Display the result gotten without pre-processing and this two new results, which one is better?
#
# [answer cell](#preprocessing)

# %%
kernel11 = np.ones((11,11),np.float32)/(11*11)

coinsmean = cv2.filter2D(coins, -1, kernel11, borderType= cv2.BORDER_REFLECT)
coinsmedian = cv2.medianBlur(coins, 11)

coinsisomean = cv2.filter2D(coinsmean, -1, isotropic, borderType= cv2.BORDER_REFLECT)
[thresh, coinsisomean] = cv2.threshold(coinsisomean, 120, 255, cv2.THRESH_BINARY)

coinsisomed = cv2.filter2D(coinsmedian, -1, isotropic, borderType= cv2.BORDER_REFLECT)

plt.figure('histograms median')
plt.hist(coinsisomed.ravel(),256,[0,256]),plt.title('Original') 
plt.show()

[thresh, coinsisomed] = cv2.threshold(coinsisomed, 25, 255, cv2.THRESH_BINARY)


plt.figure()
plt.subplot(221),plt.imshow(coinsbiniso, cmap = 'gray', vmin = 0, vmax = 255),plt.title('No blur filter')
plt.axis('off')
plt.subplot(223),plt.imshow(coinsisomean, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Mean filter')
plt.axis('off')
plt.subplot(224),plt.imshow(coinsisomed, cmap = 'gray', vmin = 0, vmax = 255),plt.title('Median filter')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Composing images**
#
# In this last exercise we want the contour of the coins to appear in red over the original image. For this remember that color images have three matrices (from the fisrt exercise look the color spaces and last point), you will need [arithmetic operations](https://docs.opencv.org/3.2.0/d0/d86/tutorial_py_image_arithmetics.html) ant to operate bit by bit on this matrices.
# Display this final image.
#
# [answer cell](#end)

# %%
coinsRGB = cv2.cvtColor(coins, cv2.COLOR_GRAY2RGB)
Bnew = np.zeros((coins.shape), np.uint8)
Gnew = np.zeros((coins.shape), np.uint8)
coinstag = cv2.merge((coinsisomed,Gnew,Bnew))

plt.figure(200)
plt.imshow(coinstag)
plt.axis('off')
plt.show()

coinsseg = cv2.add(coinsRGB, coinstag)
#bitwise_or
plt.figure(201)
plt.imshow(coinsseg)
plt.axis('off')
plt.show()

plt.figure('coinscolor')
plt.imshow(coinsseg, vmin = 0, vmax = 255)
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\anusk\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# <img src="data:image/png;base64,..." width="640">
# C:\Users\anusk\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2>Cells with the answer images</h2>

# %% [markdown]
# White noise
# <a id='whitenoise'></a>
#
# ![whitenoise](answerimages/whitenoise.PNG)

# %% [markdown]
# White noise coins
# <a id='whitecoins'></a>
#
# ![whitecoins](answerimages/coinsgaussian.PNG)

# %% [markdown]
# Salt and pepper coins
# <a id='coinssp'></a>
#
# ![coinssp](answerimages/coinssp.PNG)

# %% [markdown]
# Averaging filter
# <a id='avgfilter'></a>
#
# ![avgfilter](answerimages/avgfilter.PNG)

# %% [markdown]
# Padding
# <a id='padding'></a>
#
# ![whitenoise](answerimages/padding.PNG)

# %% [markdown]
# Median filter
# <a id='medianfilter'></a>
#
# ![medianfilter](answerimages/medianfilter.PNG)

# %% [markdown]
# Prewitt filter
# <a id='prewitt'></a>
#
# ![medianfilter](answerimages/prewitt.PNG)

# %% [markdown]
# Prewitt binary
# <a id='prewittbinary'></a>
#
# ![prewittbinary](answerimages/prewittbinary.PNG)

# %% [markdown]
# Isotropic filter
# <a id='isotropic'></a>
#
# ![Isotropic](answerimages/isotropic.PNG)

# %% [markdown]
# Pre-processing
# <a id='preprocessing'></a>
#
# ![preprocessing](answerimages/preprocessing.PNG)

# %% [markdown]
# Composing images
# <a id='end'></a>
#
# ![end](answerimages/end.PNG)
