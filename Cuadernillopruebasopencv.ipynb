# %% [markdown]
# # Cuadernillo de prueba para empezar con OpenCV

# %%
#importamos librerías necesarias
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('cutiepie.jpg',0) #carga la imagen en grises 2º argumento indica grises

#mostrar imagen en el cuadernillo
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# <h2>Operaciones básicas</h2>

# %% [markdown]
# Acceder a pixeles específicos
#
# OpenCV guarda imagenes en color como BGR en lugar de RGB

# %%
img2 = cv2.imread('cutiepie.jpg')
px = img2[20,20]
print('valor pixel 20,20')
print(px) #Enseñavalores BGR

# accessing RED value
print('red 10,10')
print(img2.item(10,10,2))
# Out:
# valor pixel 20,20
# [135  90  56]
# red 10,10
# 66

# %% [markdown]
# Propiedades y tipo de imagen

# %%
# image shape dice nº de columnas, filas y canales
print('shape:')
print(img.shape)
print(img2.shape)

# size devuelve píxeles
print('size:')
print(img.size)
print(img2.size)

#dtype devuelve tipo de imagen
print('type:')
print(img.dtype)
print(img2.dtype)
# Out:
# shape:
# (547, 599)
# (547, 599, 3)
# size:
# 327653
# 982959
# type:
# uint8
# uint8
